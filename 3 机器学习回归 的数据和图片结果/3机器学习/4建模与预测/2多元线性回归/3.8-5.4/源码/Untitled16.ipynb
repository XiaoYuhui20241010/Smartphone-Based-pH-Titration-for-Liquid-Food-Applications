# %%
import numpy as np
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error, r2_score

# %%
# 读取数据集
df = pd.read_csv("G:/JMU/passage/picture/all/blue.csv")

# 将特征和目标变量分离
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# 划分训练集和测试集
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# 创建模型并训练
model = LinearRegression()
model.fit(X_train, y_train)

# 预测测试集结果
y_pred = model.predict(X_test)

# 计算评价指标
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# 输出评价指标
print('均方误差: ', mse)
print('平均绝对误差: ', mae)
print('判定系数: ', r2)
# Out:
# 均方误差:  0.0004113624513151728
# 平均绝对误差:  0.015951673242164892
# 判定系数:  0.9974881289890533

# %%
#在训练集上的评价指标
# 预测训练集结果
y_predtrain = model.predict(X_train)

# 计算评价指标
mse_train = mean_squared_error(y_train, y_predtrain)
mae_train = mean_absolute_error(y_train, y_predtrain)
r2_train = r2_score(y_train, y_predtrain)

# 输出评价指标
print('均方误差: ', mse_train)
print('平均绝对误差: ', mae_train)
print('判定系数: ', r2_train)
# Out:
# 均方误差:  9.105825940514634e-05
# 平均绝对误差:  0.007870465840186417
# 判定系数:  0.9996207028039172

# %%
# 绘制预测-观测图
fig, ax = plt.subplots()
ax.scatter(y_pred, y_test, s=10)
ax.plot([3.8,5.4], [3.8,5.4], '--', color='gray', label='Perfect Calibration')
ax.set_xlabel('Predicted Value')
ax.set_ylabel('Observed Value')
ax.legend(loc='lower right')
plt.title('test')
plt.rcParams['savefig.dpi'] = 300 #图片像素
plt.rcParams['figure.dpi'] = 300 #分辨率
plt.show()
plt.savefig('plot1.png', dpi=300)

# %%
#导入预测文件
data_pre = pd.read_csv("G:/JMU/passage/picture/test/blue.csv")
x_pre = data_pre.iloc[:, :-1]
# 利用预测
y_pre1 = model.predict(x_pre)
y_ture = data_pre.iloc[:, -1]

# 计算评价指标
mse1 = mean_squared_error(y_ture, y_pre1)
mae1 = mean_absolute_error(y_ture, y_pre1)
r21 = r2_score(y_ture, y_pre1)

# 输出评价指标
print('Mean Squared Error: ', mse1)
print('Mean Absolute Error: ', mae1)
print('R² Score: ', r21)

# 绘制预测-观测图

fig, ax = plt.subplots()
ax.scatter(y_pre1, y_ture, s=10)
ax.plot([3.8,5.4], [3.8,5.4], '--', color='gray', label='Perfect Calibration')
ax.set_xlabel('Predicted Value')
ax.set_ylabel('Observed Value')
ax.legend(loc='lower right')
plt.title('prediction')
plt.rcParams['savefig.dpi'] = 300 #图片像素
plt.rcParams['figure.dpi'] = 300 #分辨率
plt.show()
plt.savefig('plot1.png', dpi=300)
# Out:
# Mean Squared Error:  0.003884588168619463
# Mean Absolute Error:  0.05106898957556816
# R² Score:  0.9831873303334041
